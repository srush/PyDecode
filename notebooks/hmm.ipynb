# %% [markdown]
# A Constrained HMM Example
# ---------------------

# %%
import pydecode.hyper as ph
import pydecode.display as display
from collections import namedtuple
import pydecode.chart as chart

# %% [markdown]
# We begin by constructing the HMM probabilities.

# %%
# The emission probabilities.
emission = {'ROOT' :  {'ROOT' : 1.0},
            'the' :  {'D': 0.8, 'N': 0.1, 'V': 0.1},
            'dog' :  {'D': 0.1, 'N': 0.8, 'V': 0.1},
            'walked' : {'V': 1},
            'in' :   {'D': 1},
            'park' : {'N': 0.1, 'V': 0.9},
            'END' :  {'END' : 1.0}}
      

# The transition probabilities.
transition = {'D' :    {'D' : 0.1, 'N' : 0.8, 'V' : 0.1, 'END' : 0},
              'N' :    {'D' : 0.1, 'N' : 0.1, 'V' : 0.8, 'END' : 0},
              'V' :    {'D' : 0.4, 'N' : 0.3, 'V' : 0.3, 'END' : 0},
              'ROOT' : {'D' : 0.4, 'N' : 0.3, 'V' : 0.3}}

# The sentence to be tagged.
sentence = 'the dog walked in the park'

# %% [markdown]
# Next we specify the the index set using namedtuples.

# %%
class Bigram(namedtuple("Bigram", ["word", "tag", "prevtag"])):
    def __str__(self): return "%s -> %s"%(self.prevtag, self.tag)
class Tagged(namedtuple("Tagged", ["position", "word", "tag"])):
    def __str__(self): return "%s %s"%(self.word, self.tag)

# %%
def build_weights(bigram):
    return transition[bigram.prevtag][bigram.tag] + emission[bigram.word][bigram.tag]

# %%
def viterbi(chart):
    words = ["ROOT"] + sentence.strip().split(" ") + ["END"]
    c.init(Tagged(0, "ROOT", "ROOT"))    
    for i, word in enumerate(words[1:], 1):
        prev_tags = emission[words[i - 1]].keys()
        for tag in emission[word].iterkeys():
            c[Tagged(i, word, tag)] = \
                c.sum([c[key] * c.sr(Bigram(word, tag, prev)) 
                       for prev in prev_tags 
                       for key in [Tagged(i - 1, words[i - 1], prev)] if key in c])
    return c

# %% [markdown]
# Now we are ready to build the hypergraph topology itself.

# %%
c = chart.ChartBuilder(lambda a: build_weights(Bigram(*a)))
the_chart = viterbi(c)
the_chart.finish()
# Out:
# the V 1.4
# the D 2.2
# the N 1.4
# dog V 2.4000000000000004
# dog D 2.4000000000000004
# dog N 3.8000000000000003
# walked V 5.6000000000000005
# in D 7.0
# the V 7.2
# the D 7.9
# the N 7.9
# park V 9.600000000000001
# park N 8.8
# END END 10.600000000000001
# 10.600000000000001

# %%
c = chart.ChartBuilder(lambda a: build_weights(Bigram(*a)), 
                       chart.ViterbiSemiRing)
the_chart = viterbi(c)
the_chart.finish()
# Out:
# the V 0.4
# the D 1.2000000000000002
# the N 0.4
# dog V 1.4000000000000001
# dog D 1.4000000000000001
# dog N 2.8000000000000003
# walked V 4.6000000000000005
# in D 6.0
# the V 6.2
# the D 6.9
# the N 6.9
# park V 8.600000000000001
# park N 7.800000000000001
# END END 9.600000000000001
# 9.600000000000001

# %%
c = chart.ChartBuilder(lambda a: Bigram(*a), 
                       chart.HypergraphSemiRing, 
                       build_hypergraph = True)
the_chart = viterbi(c)
hypergraph = the_chart.finish()
# Out:
# start
# the V <pydecode.semiring.HypergraphSemiRing instance at 0x539f878>
# [([<pydecode.hyper.Node object at 0x46083a0>], Bigram(word='the', tag='V', prevtag='ROOT'))]
# the D <pydecode.semiring.HypergraphSemiRing instance at 0x539f518>
# [([<pydecode.hyper.Node object at 0x46083a0>], Bigram(word='the', tag='D', prevtag='ROOT'))]
# the N <pydecode.semiring.HypergraphSemiRing instance at 0x539f7e8>
# [([<pydecode.hyper.Node object at 0x46083a0>], Bigram(word='the', tag='N', prevtag='ROOT'))]
# dog V <pydecode.semiring.HypergraphSemiRing instance at 0x5387758>
# [([<pydecode.hyper.Node object at 0x46088c8>], Bigram(word='dog', tag='V', prevtag='V')), ([<pydecode.hyper.Node object at 0x4608080>], Bigram(word='dog', tag='V', prevtag='D')), ([<pydecode.hyper.Node object at 0x46080a8>], Bigram(word='dog', tag='V', prevtag='N'))]
# dog D <pydecode.semiring.HypergraphSemiRing instance at 0x5387ab8>
# [([<pydecode.hyper.Node object at 0x46088c8>], Bigram(word='dog', tag='D', prevtag='V')), ([<pydecode.hyper.Node object at 0x4608080>], Bigram(word='dog', tag='D', prevtag='D')), ([<pydecode.hyper.Node object at 0x46080a8>], Bigram(word='dog', tag='D', prevtag='N'))]
# dog N <pydecode.semiring.HypergraphSemiRing instance at 0x5387b48>
# [([<pydecode.hyper.Node object at 0x46088c8>], Bigram(word='dog', tag='N', prevtag='V')), ([<pydecode.hyper.Node object at 0x4608080>], Bigram(word='dog', tag='N', prevtag='D')), ([<pydecode.hyper.Node object at 0x46080a8>], Bigram(word='dog', tag='N', prevtag='N'))]
# walked V <pydecode.semiring.HypergraphSemiRing instance at 0x5387c20>
# [([<pydecode.hyper.Node object at 0x46086c0>], Bigram(word='walked', tag='V', prevtag='V')), ([<pydecode.hyper.Node object at 0x46087d8>], Bigram(word='walked', tag='V', prevtag='D')), ([<pydecode.hyper.Node object at 0x4608490>], Bigram(word='walked', tag='V', prevtag='N'))]
# in D <pydecode.semiring.HypergraphSemiRing instance at 0x5387758>
# [([<pydecode.hyper.Node object at 0x4608148>], Bigram(word='in', tag='D', prevtag='V'))]
# the V <pydecode.semiring.HypergraphSemiRing instance at 0x539f7e8>
# [([<pydecode.hyper.Node object at 0x4608468>], Bigram(word='the', tag='V', prevtag='D'))]
# the D <pydecode.semiring.HypergraphSemiRing instance at 0x40f0ef0>
# [([<pydecode.hyper.Node object at 0x4608468>], Bigram(word='the', tag='D', prevtag='D'))]
# the N <pydecode.semiring.HypergraphSemiRing instance at 0x53847e8>
# [([<pydecode.hyper.Node object at 0x4608468>], Bigram(word='the', tag='N', prevtag='D'))]
# park V <pydecode.semiring.HypergraphSemiRing instance at 0x5384f80>
# [([<pydecode.hyper.Node object at 0x539a8a0>], Bigram(word='park', tag='V', prevtag='V')), ([<pydecode.hyper.Node object at 0x539aeb8>], Bigram(word='park', tag='V', prevtag='D')), ([<pydecode.hyper.Node object at 0x539a620>], Bigram(word='park', tag='V', prevtag='N'))]
# park N <pydecode.semiring.HypergraphSemiRing instance at 0x5384b00>
# [([<pydecode.hyper.Node object at 0x539a8a0>], Bigram(word='park', tag='N', prevtag='V')), ([<pydecode.hyper.Node object at 0x539aeb8>], Bigram(word='park', tag='N', prevtag='D')), ([<pydecode.hyper.Node object at 0x539a620>], Bigram(word='park', tag='N', prevtag='N'))]
# END END <pydecode.semiring.HypergraphSemiRing instance at 0x53841b8>
# [([<pydecode.hyper.Node object at 0x539ad78>], Bigram(word='END', tag='END', prevtag='V')), ([<pydecode.hyper.Node object at 0x539ae90>], Bigram(word='END', tag='END', prevtag='N'))]

# %% [markdown]
# Step 3: Construct the weights.

# %%
weights = ph.Weights(hypergraph).build(build_weights)

# %%
# Find the viterbi path.
path, vchart = ph.best_path(hypergraph, weights)
print weights.dot(path)

# Output the path.
[hypergraph.label(edge) for edge in path.edges]
# Out:
# 9.6
# [Bigram(word='the', tag='D', prevtag='ROOT'),
#  Bigram(word='dog', tag='N', prevtag='D'),
#  Bigram(word='walked', tag='V', prevtag='N'),
#  Bigram(word='in', tag='D', prevtag='V'),
#  Bigram(word='the', tag='N', prevtag='D'),
#  Bigram(word='park', tag='V', prevtag='N'),
#  Bigram(word='END', tag='END', prevtag='V')]

# %%
format = display.HypergraphPathFormatter(hypergraph, [path])
display.to_ipython(hypergraph, format)

# %% [markdown]
# We can also use a custom fancier formatter. These attributes are from graphviz (http://www.graphviz.org/content/attrs)

# %%
class HMMFormat(display.HypergraphPathFormatter):
    def hypernode_attrs(self, node):
        label = self.hypergraph.node_label(node)
        return {"label": label.tag, "shape": ""}
    def hyperedge_node_attrs(self, edge):
        return {"color": "pink", "shape": "point"}
    def hypernode_subgraph(self, node):
        label = self.hypergraph.node_label(node)
        return [("cluster_" + str(label.position), None)]
    def subgraph_format(self, subgraph):
        return {"label": (["ROOT"] + sentence.split() + ["END"])[int(subgraph.split("_")[1])],
                "rank" : "same"}
    def graph_attrs(self): return {"rankdir":"RL"}
format = HMMFormat(hypergraph, [path])
display.to_ipython(hypergraph, format)

# %% [markdown]
# PyDecode also allows you to add extra constraints to the problem. As an example we can add constraints to enfore that the tag of "dog" is the same tag as "park".

# %%
def cons(tag): return "tag_%s"%tag

def build_constraints(bigram):
    if bigram.word == "dog":
        return [(cons(bigram.tag), 1)]
    elif bigram.word == "park":
        return [(cons(bigram.tag), -1)]
    return []

constraints = \
    ph.Constraints(hypergraph).build( 
                   [(cons(tag), 0) for tag in ["D", "V", "N"]], 
                   build_constraints)

# %% [markdown]
# This check fails because the tags do not agree.

# %%
print "check", constraints.check(path)
# Out:
# check [<pydecode.hyper.Constraint object at 0x46051d0>, <pydecode.hyper.Constraint object at 0x4605590>]

# %% [markdown]
# Solve instead using subgradient.

# %%
gpath, duals = ph.best_constrained(hypergraph, weights, constraints)

# %%
for d in duals:
    print d.dual, d.constraints
# Out:
# 9.6 [<pydecode.hyper.Constraint object at 0x46051b0>, <pydecode.hyper.Constraint object at 0x4605150>]
# 8.8 []

# %%
display.report(duals)

# %%
import pydecode.lp as lp
hypergraph_lp = lp.HypergraphLP.make_lp(hypergraph, weights)
path = hypergraph_lp.solve()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-50f1f023eb17> in <module>()
#       1 import pydecode.lp as lp
# ----> 2 hypergraph_lp = lp.HypergraphLP.make_lp(hypergraph, weights)
#       3 path = hypergraph_lp.solve()
#
# /home/srush/Projects/decoding/python/pydecode/lp.pyc in make_lp(hypergraph, weights, name, var_type)
#     124         # x(v) = \sum_{e : h(e) = v} x(e)
#     125         for node in hypergraph.nodes:
# --> 126             if node.is_terminal(): continue
#     127             prob += node_vars[node.id] == sum([edge_vars[edge.id]
#     128                                             for edge in node.edges])
#
# TypeError: 'bool' object is not callable

# %%
# Output the path.
for edge in gpath.edges:
    print hypergraph.label(edge)

# %%
print "check", constraints.check(gpath)
print "score", weights.dot(gpath)

# %%
format = HMMFormat(hypergraph, [path, gpath])
display.to_ipython(hypergraph, format)

# %%
for constraint in constraints:
    print constraint.label

# %%
class HMMConstraintFormat(display.HypergraphConstraintFormatter):
    def hypernode_attrs(self, node):
        label = self.hypergraph.node_label(node)
        return {"label": label.tag, "shape": ""}
    def hyperedge_node_attrs(self, edge):
        return {"color": "pink", "shape": "point"}
    def hypernode_subgraph(self, node):
        label = self.hypergraph.node_label(node)
        return [("cluster_" + str(label.position), None)]
    def subgraph_format(self, subgraph):
        return {"label": (sentence.split() + ["END"])[int(subgraph.split("_")[1])]}

format = HMMConstraintFormat(hypergraph, constraints)
display.to_ipython(hypergraph, format)

# %% [markdown]
# Pruning

# %%
pruned_hypergraph, pruned_weights = ph.prune_hypergraph(hypergraph, weights, 0.8)

# %%
display.to_ipython(pruned_hypergraph, HMMFormat(pruned_hypergraph, []))

# %%
very_pruned_hypergraph, _ = ph.prune_hypergraph(hypergraph, weights, 0.9)
